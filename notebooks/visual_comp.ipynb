# %%
import sys
import random
import time
sys.path.append('..')
from utils.visual_comparison import (
    gen_comparison,
    gen_comparison_with_local_mag,
    gen_comparison_with_local_edges,
    gen_comparison_with_local_edges2,
    get_random_img_names,
    gen_random_area
)

# %%
# -- LSUI-Test -- #

# random.seed(time.time())
# img_name_list = get_random_img_names('/DataA/pwz/workshop/Datasets/LSUI/test/inp', 5)
# print(img_name_list)

img_name_list = (
    '1161.jpg', '122.jpg', '1368.jpg', '1676.jpg', '1832.jpg', '4952.jpg'
)

img_dirs = {
    'Input': '/DataA/pwz/workshop/Datasets/LSUI/test/inp',
    'UT-UIE': '/DataA/pwz/workshop/UTUIE/results/LSUI_Test',
    'SyreaNet': '/DataA/pwz/workshop/SyreaNet/output/LSUI_Test',
    'WaterNet': '/DataA/pwz/workshop/Water-Net_Code/results/LSUI_Test',
    'UGAN': '/DataA/pwz/workshop/FUnIE-GAN-Orig/PyTorch/results/ugan/LSUI_Test/single/predicted',
    'FUnIE-GAN': '/DataA/pwz/workshop/FUnIE-GAN-Orig/PyTorch/results/funiegan/LSUI_Test/single/predicted',
    'UWCNN': '/DataA/pwz/workshop/UWCNN/results/LSUI_Test',
    'SGUIE-Net': '/DataA/pwz/workshop/SGUIE-Net_Simple/results/LSUI_Test/pretrained',
    'Cycle-GAN': '/DataA/pwz/workshop/pytorch-CycleGAN-and-pix2pix/results/new_uw4_cycle_gan_resnet_9blocks_percep1.0/test_20/LSUI_Test/images/fake',
    'ERD(Ours)': '../results/ie5/ra/LSUI_03/LSUI/epoch_299/single/predicted',
    'Ground Truth': '/DataA/pwz/workshop/Datasets/LSUI/test/ref'
}

font_cfg = {
    'fontfamily': 'Nimbus Roman',
    'fontsize': 32,
}
gen_comparison(img_name_list, img_dirs, font_cfg=font_cfg, title_y=-0.2,
               save_fig=True, save_folder='../figures/',
               save_fmt='eps', save_name='ref_comp_diff_methods_lsui')

# %%
# -- UIEB100 -- #

# random.seed(time.time())
# img_name_list = get_random_img_names('/DataA/pwz/workshop/Datasets/UIEB100/raw/', 5)
# print(img_name_list)

img_name_list = (
    '190_img_.png', '402_img_.png', '411_img_.png', '917_img_.png', '190_img_.png', '493_img_.png'
)

img_dirs = {
    'Input': '/DataA/pwz/workshop/Datasets/UIEB100/raw',
    'UT-UIE': '/DataA/pwz/workshop/UTUIE/results/UIEB100',
    'SyreaNet': '/DataA/pwz/workshop/SyreaNet/output/UIEB100',
    'WaterNet': '/DataA/pwz/workshop/Water-Net_Code/results/UIEB100',
    'UGAN': '/DataA/pwz/workshop/FUnIE-GAN-Orig/PyTorch/results/ugan/UIEB100/single/predicted',
    'FUnIE-GAN': '/DataA/pwz/workshop/FUnIE-GAN-Orig/PyTorch/results/funiegan/UIEB100/single/predicted',
    'UWCNN': '/DataA/pwz/workshop/UWCNN/results/UIEB100',
    'SGUIE-Net': '/DataA/pwz/workshop/SGUIE-Net_Simple/results/UIEB100',
    'Cycle-GAN': '/DataA/pwz/workshop/pytorch-CycleGAN-and-pix2pix/results/new_uw4_cycle_gan_resnet_9blocks_percep1.0/test_20/UIEB100/images/fake',
    'ERD(Ours)': '../results/ie5/ra/LSUI_03/UIEB100/epoch_299/single/predicted',
    'Ground Truth': '/DataA/pwz/workshop/Datasets/UIEB100/reference'
}

font_cfg = {
    'fontfamily': 'Nimbus Roman',
    'fontsize': 32,
}
gen_comparison(img_name_list, img_dirs, font_cfg=font_cfg, title_y=-0.2,
               save_fig=True, save_folder='../figures/',
               save_fmt='eps', save_name='ref_comp_diff_methods_uieb100')

# %%
# -- U45 -- #

# random.seed(time.time())
# img_name_list = get_random_img_names('/DataA/pwz/workshop/Datasets/U45/U45', 5)
# print(img_name_list)

img_dirs = {
    'Input': '/DataA/pwz/workshop/Datasets/U45/U45',
    'UT-UIE': '/DataA/pwz/workshop/UTUIE/results/U45',
    'SyreaNet': '/DataA/pwz/workshop/SyreaNet/output/U45',
    'WaterNet': '/DataA/pwz/workshop/Water-Net_Code/results/U45',
    'UGAN': '/DataA/pwz/workshop/FUnIE-GAN-Orig/PyTorch/results/ugan/U45/single/predicted',
    'FUnIE-GAN': '/DataA/pwz/workshop/FUnIE-GAN-Orig/PyTorch/results/funiegan/U45/single/predicted',
    'UWCNN': '/DataA/pwz/workshop/UWCNN/results/U45_typeII',
    'SGUIE-Net': '/DataA/pwz/workshop/SGUIE-Net_Simple/results/U45',
    'Cycle-GAN': '/DataA/pwz/workshop/pytorch-CycleGAN-and-pix2pix/results/new_uw4_cycle_gan_resnet_9blocks_percep1.0/test_20/U45/images/fake',
    'ERD(Ours)': '../results/ie5/ra/LSUI_03/U45/epoch_299/single/predicted',
}

img_name_list = (
    'u45_00001.png', 'u45_00005.png', 'u45_00018.png', 'u45_00030.png', 'u45_00038.png', 'u45_00041.png'
)

font_cfg = {
    'fontfamily': 'Nimbus Roman',
    'fontsize': 32,
}
gen_comparison(img_name_list, img_dirs, font_cfg=font_cfg, title_y=-0.2,
               save_fig=True, save_folder='../figures/',
               save_fmt='eps', save_name='nonref_comp_diff_methods_u45')

# %%
# -- U45 -- #
# Edge Detection Comparison

img_dirs_part1 = {
    'Input': '/DataA/pwz/workshop/Datasets/U45/U45',
    'UT-UIE': '/DataA/pwz/workshop/UTUIE/results/U45',
    'UGAN': '/DataA/pwz/workshop/FUnIE-GAN-Orig/PyTorch/results/ugan/U45/single/predicted',
    'FUnIE-GAN': '/DataA/pwz/workshop/FUnIE-GAN-Orig/PyTorch/results/funiegan/U45/single/predicted',
    'UWCNN': '/DataA/pwz/workshop/UWCNN/results/U45_typeII',
    'ERD(Ours)': '../results/ie5/ra/LSUI_03/U45/epoch_299/single/predicted',
}

img_dirs_part2 = {
    'Input': '/DataA/pwz/workshop/Datasets/U45/U45',
    'SyreaNet': '/DataA/pwz/workshop/SyreaNet/output/U45',
    'WaterNet': '/DataA/pwz/workshop/Water-Net_Code/results/U45',
    'SGUIE-Net': '/DataA/pwz/workshop/SGUIE-Net_Simple/results/U45',
    'Cycle-GAN': '/DataA/pwz/workshop/pytorch-CycleGAN-and-pix2pix/results/new_uw4_cycle_gan_resnet_9blocks_percep1.0/test_20/U45/images/fake',
    'ERD(Ours)': '../results/ie5/ra/LSUI_03/U45/epoch_299/single/predicted',
}

img_name_list = (
    'u45_00001.png', 'u45_00005.png', 'u45_00026.png', 'u45_00030.png', 'u45_00022.png'
)
local_areas = (
    (42, 92, 122, 169), (20, 4, 128, 120), (132,0,228,98), (31, 50, 95, 114), (162,1,254,90)
)

# random.seed(time.time())
# img_name_list = get_random_img_names('/DataA/pwz/workshop/Datasets/U45/U45', 4)
# print(img_name_list)
# local_areas = [gen_random_area(256,256,64,64) for _ in range(len(img_name_list))]
# print(local_areas)

font_cfg = {
    'fontfamily': 'Nimbus Roman',
    'fontsize': 32,
}

gen_comparison_with_local_edges(img_name_list, local_areas, img_dirs_part1, font_cfg=font_cfg, title_y=-0.3,
               save_fig=True, save_folder='../figures/',
               save_fmt='eps', save_name='edge_comp_diff_methods_u45_part01')
gen_comparison_with_local_edges(img_name_list, local_areas, img_dirs_part2, font_cfg=font_cfg, title_y=-0.3,
               save_fig=True, save_folder='../figures/',
               save_fmt='eps', save_name='edge_comp_diff_methods_u45_part02')
